# %%
from verify_spans import load_spans

# %%
load_spans(
    votes_dir="/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/verifiers-experiments/Qwen3-30B-A3B-new-prompts-votes-merged/",
    out_dir="/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/verifiers-experiments/outputs/",
    textract_dir="/Volumes/MyDataDrive/thesis/rvl-test-preprocessing/testset-documents-ocr-idp/"
)
# Out:
# ✅ votes_fgbf0249_page1.json_verified.json already exists – skipping.
# ✅ votes_fgbf0249_page2.json_verified.json already exists – skipping.
# ✅ votes_fgbf0249_page5.json_verified.json already exists – skipping.
# ✅ votes_fgcg0076_page1.json_verified.json already exists – skipping.
# ✅ votes_fgck0201_page1.json_verified.json already exists – skipping.
# ✅ votes_fgcn0082_page1.json_verified.json already exists – skipping.
# ✅ votes_fgdl0043_page3.json_verified.json already exists – skipping.
# ✅ votes_fgdn0202_page1.json_verified.json already exists – skipping.
# ✅ votes_fgdp0140_page1.json_verified.json already exists – skipping.
# ✅ votes_fgdy0093_page2.json_verified.json already exists – skipping.
# ✅ votes_fgfv0233_page1.json_verified.json already exists – skipping.
# ✅ votes_fgfy0251_page1.json_verified.json already exists – skipping.
# ✅ votes_fggl0102_page1.json_verified.json already exists – skipping.
# ✅ votes_fgjc0018_page1.json_verified.json already exists – skipping.
# ...

# %%
from langfuse.openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path="/Volumes/MyDataDrive/thesis/code-2/.env")


deepinfra_client = OpenAI(
    api_key=os.getenv("DEEPINFRA_API_KEY"),
    base_url="https://api.deepinfra.com/v1/openai"
)
