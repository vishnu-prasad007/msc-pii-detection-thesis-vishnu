# %%
import json
import majority_voting

# %%
votes_dir = "/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/Qwen3-30B-A3B-new-prompts-1-per_page_votes_merged/"
MODEL_DIR = "Qwen3-30B-A3B-new-prompts-1/"
out_dir= "/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/majority-voting/" + MODEL_DIR

majority_voting.score_all_jsons_global(votes_dir, out_dir)
# Out:
# Processing: votes_fgbf0249_page1.json
# Processing /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/Qwen3-30B-A3B-new-prompts-1-per_page_votes_merged/votes_fgbf0249_page1.json with 3 annotators
# Wrote scored file: /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/majority-voting/Qwen3-30B-A3B-new-prompts-1/votes_fgbf0249_page1.json
# Processing: votes_fgbf0249_page2.json
# Processing /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/Qwen3-30B-A3B-new-prompts-1-per_page_votes_merged/votes_fgbf0249_page2.json with 3 annotators
# Wrote scored file: /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/majority-voting/Qwen3-30B-A3B-new-prompts-1/votes_fgbf0249_page2.json
# Processing: votes_fgbf0249_page5.json
# Processing /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/Qwen3-30B-A3B-new-prompts-1-per_page_votes_merged/votes_fgbf0249_page5.json with 3 annotators
# ...
