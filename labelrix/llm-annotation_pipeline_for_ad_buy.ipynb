# %%
import json
import segment_lines
import annotation_filters
import score
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
def main():
    MODEL = "meta-llama/Llama-3.3-70B-Instruct"
    MODEL_DIR = "Llama-3.3-70B-Instruct"
    benchmark_file_list_path = "/Volumes/MyDataDrive/thesis/code-2/src/labelrix/benchmark-file-list.json"
    out_path = "/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/"

    with open(benchmark_file_list_path, "r") as benchmark_file_list_file:
        data = json.load(benchmark_file_list_file)
    
    votes_out_dir = out_path + MODEL_DIR + "-per_page_votes"
    votes_merged_dir = out_path + MODEL_DIR + "-per_page_votes_merged"

    os.makedirs(votes_out_dir, exist_ok=True)
    os.makedirs(votes_merged_dir, exist_ok=True)

    def _extract_with_log(file_path, pages, model, out_dir):
        print(f"[PICKED] {file_path}")
        try:
            segment_lines.extract_votes(file_path, pages, model, out_dir=out_dir)
            print(f"[DONE]   {file_path}")
        except Exception as e:
            print(f"[ERROR]  {file_path} -> {e}")
            raise

    # Parallel per-file extraction (30 at a time)
    futures = []
    with ThreadPoolExecutor(max_workers=30) as executor:
        for key, value in data.items():
            filename = key
            pages = value['pages']
            file_path = value['file_path']
            file_value = value['file_path'].split("/")[-1]

            futures.append(
                executor.submit(
                    _extract_with_log,
                    file_path,
                    pages,
                    MODEL,
                    votes_out_dir
                )
            )

        for fut in as_completed(futures):
            try:
                fut.result()
            except Exception as e:
                print(f"Extraction failed: {e}")
    
    # Here we apply filtering
    annotation_filters.process_directory_to_json(
        in_dir=votes_out_dir,
        out_dir=votes_merged_dir,
        iou_thresh=0.5,
        overlap_thresh=0.9
    )

    score_dir = out_path + MODEL_DIR + "/"
    score.score_all_jsons_global(votes_merged_dir, out_dir=score_dir)

# %%
if __name__ == "__main__":
    main()
# Out:
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/e8d41204-64eb-9f4b-608e-5593933aca41.json[PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/456300-sept-17-23-2012-11953-13474707086771-_-pdf.json
#
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/eabf486e-2ff6-c060-68b7-fcf5363bde66.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f5a1056c-ac79-aac8-6099-87821a840150.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f9a59888-b508-9792-d356-1d36de82c212.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f56e2fc1-7f41-68e3-bfe5-06176b9a2e8a.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/fdf168ea-c840-1465-710a-762427b285c3.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/ef640e66-1f79-701f-61d7-e968acb9e3fc.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/eff55361-0e39-53a1-da0b-a337a361b66b.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f21fcdd1-214c-c145-29cc-362e0b0ef1e3.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/e038716a-f9a1-2ab5-e72b-eb2f00f26981.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f7635eed-5555-27b6-780f-8386863b25ca.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/ff9c72fa-8267-5701-5492-e8cbf336e101.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/e910d31f-0c5a-5041-1a4d-1f1b39606992.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/0a32ce11-7ed9-14ee-8856-6a1edfad9ff3.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/ee19ec76-3531-254f-c21f-869b6cf0916c.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/faa55a77-9090-22ac-fe9b-32ab3f026300.json
# [PICKED] /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/efca8764-0dfb-3f1c-beb9-f629991435bb.json
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Person Name after retries: No <json-start>…<json-end> block found
# Skipping file 456300-sept-17-23-2012-11953-13474707086771-_-pdf.pdf_page1
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/456300-sept-17-23-2012-11953-13474707086771-_-pdf.json
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Phone Number after retries: No <json-start>…<json-end> block found
# Skipping file ff9c72fa-8267-5701-5492-e8cbf336e101.pdf_page2
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/ff9c72fa-8267-5701-5492-e8cbf336e101.json
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Date after retries: Invalid control character at: line 5 column 12 (char 118)
# Skipping file ee19ec76-3531-254f-c21f-869b6cf0916c.pdf_page1
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Person Name after retries: No <json-start>…<json-end> block found
# Skipping file efca8764-0dfb-3f1c-beb9-f629991435bb.pdf_page1
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Person Name after retries: No <json-start>…<json-end> block found
# Skipping file faa55a77-9090-22ac-fe9b-32ab3f026300.pdf_page1
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/faa55a77-9090-22ac-fe9b-32ab3f026300.json
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Saved 85 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_ef640e66-1f79-701f-61d7-e968acb9e3fc.pdf_page1.csv
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Phone Number after retries: No <json-start>…<json-end> block found
# Skipping file f7635eed-5555-27b6-780f-8386863b25ca.pdf_page1
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Phone Number after retries: No <json-start>…<json-end> block found
# Skipping file eff55361-0e39-53a1-da0b-a337a361b66b.pdf_page1
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Phone Number after retries: No <json-start>…<json-end> block found
# Skipping file fdf168ea-c840-1465-710a-762427b285c3.pdf_page1
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/fdf168ea-c840-1465-710a-762427b285c3.json
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Person Name after retries: No <json-start>…<json-end> block found
# Skipping file e038716a-f9a1-2ab5-e72b-eb2f00f26981.pdf_page1
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/e038716a-f9a1-2ab5-e72b-eb2f00f26981.json
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Person Name after retries: No <json-start>…<json-end> block found
# Skipping file ee19ec76-3531-254f-c21f-869b6cf0916c.pdf_page2
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/ee19ec76-3531-254f-c21f-869b6cf0916c.json
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Phone Number after retries: No <json-start>…<json-end> block found
# Skipping file f56e2fc1-7f41-68e3-bfe5-06176b9a2e8a.pdf_page1
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Saved 159 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_f21fcdd1-214c-c145-29cc-362e0b0ef1e3.pdf_page1.csv
# Saved 126 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_f5a1056c-ac79-aac8-6099-87821a840150.pdf_page1.csv
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f5a1056c-ac79-aac8-6099-87821a840150.json
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Date after retries: No <json-start>…<json-end> block found
# Skipping file e8d41204-64eb-9f4b-608e-5593933aca41.pdf_page1
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Saved 122 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_eabf486e-2ff6-c060-68b7-fcf5363bde66.pdf_page1.csv
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Phone Number after retries: No <json-start>…<json-end> block found
# Skipping file efca8764-0dfb-3f1c-beb9-f629991435bb.pdf_page2
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/efca8764-0dfb-3f1c-beb9-f629991435bb.json
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Date after retries: No <json-start>…<json-end> block found
# Skipping file e910d31f-0c5a-5041-1a4d-1f1b39606992.pdf_page1
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/e910d31f-0c5a-5041-1a4d-1f1b39606992.json
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Saved 73 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_0a32ce11-7ed9-14ee-8856-6a1edfad9ff3.pdf_page2.csv
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/0a32ce11-7ed9-14ee-8856-6a1edfad9ff3.json
# Saved 99 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_f9a59888-b508-9792-d356-1d36de82c212.pdf_page1.csv
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Contract Number after retries: No <json-start>…<json-end> block found
# Skipping file f7635eed-5555-27b6-780f-8386863b25ca.pdf_page2
# Attempt 1/3: JSON tags not found. Retrying…
# Saved 149 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_f56e2fc1-7f41-68e3-bfe5-06176b9a2e8a.pdf_page2.csv
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Date after retries: No <json-start>…<json-end> block found
# Skipping file ef640e66-1f79-701f-61d7-e968acb9e3fc.pdf_page2
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/ef640e66-1f79-701f-61d7-e968acb9e3fc.json
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Saved 92 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_e8d41204-64eb-9f4b-608e-5593933aca41.pdf_page4.csv
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/e8d41204-64eb-9f4b-608e-5593933aca41.json
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Saved 226 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_f21fcdd1-214c-c145-29cc-362e0b0ef1e3.pdf_page2.csv
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Email Address after retries: No <json-start>…<json-end> block found
# Skipping file f56e2fc1-7f41-68e3-bfe5-06176b9a2e8a.pdf_page3
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f56e2fc1-7f41-68e3-bfe5-06176b9a2e8a.json
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Organization Name after retries: No <json-start>…<json-end> block found
# Skipping file f7635eed-5555-27b6-780f-8386863b25ca.pdf_page3
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f7635eed-5555-27b6-780f-8386863b25ca.json
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Date after retries: No <json-start>…<json-end> block found
# Skipping file eabf486e-2ff6-c060-68b7-fcf5363bde66.pdf_page2
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Date after retries: No <json-start>…<json-end> block found
# Skipping file eff55361-0e39-53a1-da0b-a337a361b66b.pdf_page2
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Date after retries: No <json-start>…<json-end> block found
# Skipping file f9a59888-b508-9792-d356-1d36de82c212.pdf_page2
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f9a59888-b508-9792-d356-1d36de82c212.json
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Phone Number after retries: No <json-start>…<json-end> block found
# Skipping file eabf486e-2ff6-c060-68b7-fcf5363bde66.pdf_page3
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/eabf486e-2ff6-c060-68b7-fcf5363bde66.json
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Contract Number after retries: No <json-start>…<json-end> block found
# Skipping file f21fcdd1-214c-c145-29cc-362e0b0ef1e3.pdf_page3
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/f21fcdd1-214c-c145-29cc-362e0b0ef1e3.json
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Saved 151 votes to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes/votes_eff55361-0e39-53a1-da0b-a337a361b66b.pdf_page3.csv
# Attempt 1/3: JSON tags not found. Retrying…
# Attempt 2/3: JSON tags not found. Retrying…
# Attempt 3/3: JSON tags not found. Retrying…
# ❌ Failed to extract Person Name after retries: No <json-start>…<json-end> block found
# Skipping file eff55361-0e39-53a1-da0b-a337a361b66b.pdf_page4
# [DONE]   /Volumes/MyDataDrive/thesis/code-2/data/ad-buy-forms/source/eff55361-0e39-53a1-da0b-a337a361b66b.json
# Wrote 46 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_f5a1056c-ac79-aac8-6099-87821a840150.pdf_page1.json
# Wrote 61 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_f21fcdd1-214c-c145-29cc-362e0b0ef1e3.pdf_page1.json
# Wrote 92 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_f21fcdd1-214c-c145-29cc-362e0b0ef1e3.pdf_page2.json
# Wrote 67 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_eff55361-0e39-53a1-da0b-a337a361b66b.pdf_page3.json
# Wrote 33 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_ef640e66-1f79-701f-61d7-e968acb9e3fc.pdf_page1.json
# Wrote 44 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_e8d41204-64eb-9f4b-608e-5593933aca41.pdf_page4.json
# Wrote 60 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_f56e2fc1-7f41-68e3-bfe5-06176b9a2e8a.pdf_page2.json
# Wrote 48 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_0a32ce11-7ed9-14ee-8856-6a1edfad9ff3.pdf_page2.json
# Wrote 54 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_eabf486e-2ff6-c060-68b7-fcf5363bde66.pdf_page1.json
# Wrote 36 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_f9a59888-b508-9792-d356-1d36de82c212.pdf_page1.json
# Wrote 38 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Llama-3.3-70B-Instruct-per_page_votes_merged/votes_eabf486e-2ff6-c060-68b7-fcf5363bde66.pdf_page2.json
# m: 0
# Annotators Accuracy : [] for PII type : Person Name
# Annotators Accuracy : [] for PII type : Email Address
# Annotators Accuracy : [] for PII type : ('Date', 'Phone Number')
# Annotators Accuracy : [] for PII type : Location
# Annotators Accuracy : [] for PII type : Organization Name
# Annotators Accuracy : [] for PII type : ('Date', 'Contract Number')
# Annotators Accuracy : [] for PII type : Invoice Number
# Annotators Accuracy : [] for PII type : ('Organization Name', 'Person Name')
# Annotators Accuracy : [] for PII type : Contract Number
# Annotators Accuracy : [] for PII type : Date
# Annotators Accuracy : [] for PII type : ('Invoice Number', 'Contract Number')
# Annotators Accuracy : [] for PII type : Phone Number
# Annotators Accuracy : [] for PII type : ('Organization Name', 'Invoice Number')
# Annotators Accuracy : [] for PII type : ('Organization Name', 'Location')
# Annotators Accuracy : [] for PII type : ('Contract Number', 'Invoice Number')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[4], line 59, in main()
#      51 annotation_filters.process_directory_to_json(
#      52     in_dir=votes_out_dir,
#      53     out_dir=votes_merged_dir,
#      54     iou_thresh=0.5,
#      55     overlap_thresh=0.9
#      56 )
#      58 score_dir = out_path + MODEL_DIR + "/"
# ---> 59 score.score_all_jsons_global(votes_merged_dir, out_dir=score_dir)
#
# File /Volumes/MyDataDrive/thesis/code-2/src/labelrix/score.py:274, in score_all_jsons_global(votes_dir, out_dir)
#     272 records_by_file[path][local_idx]['probability'] = float(p)
#     273 file_name = path.split("/")[-1].split(".")[0] + ".png"
# --> 274 bb = dimensions_map[file_name]
#     276 # Here we change to abosolute bbox
#     277 x = records_by_file[path][local_idx]['bbox'][0] * bb['original_width']
#
# KeyError: 'votes_0a32ce11-7ed9-14ee-8856-6a1edfad9ff3.png'

# %%
MODEL_DIR = "Qwen2.5-72B-Instruct"
out_path = "/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/"
votes_out_dir = out_path + MODEL_DIR + "-per_page_votes"
votes_merged_dir = out_path + MODEL_DIR + "-per_page_votes_merged"

os.makedirs(votes_out_dir, exist_ok=True)
os.makedirs(votes_merged_dir, exist_ok=True)


annotation_filters.process_directory_to_json(
        in_dir=votes_out_dir,
        out_dir=votes_merged_dir,
        iou_thresh=0.5,
        overlap_thresh=0.9
)

score_dir = out_path + MODEL_DIR + "/"
score.score_all_jsons_global(votes_merged_dir, out_dir=score_dir)
# Out:
# Wrote 24 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_f7635eed-5555-27b6-780f-8386863b25ca.pdf_page3.json
# Wrote 8 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_faa55a77-9090-22ac-fe9b-32ab3f026300.pdf_page1.json
# Wrote 14 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_f7635eed-5555-27b6-780f-8386863b25ca.pdf_page2.json
# Wrote 16 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_efca8764-0dfb-3f1c-beb9-f629991435bb.pdf_page1.json
# Wrote 12 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_ee19ec76-3531-254f-c21f-869b6cf0916c.pdf_page2.json
# Wrote 34 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_f21fcdd1-214c-c145-29cc-362e0b0ef1e3.pdf_page1.json
# Wrote 15 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_f21fcdd1-214c-c145-29cc-362e0b0ef1e3.pdf_page3.json
# Wrote 36 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_eff55361-0e39-53a1-da0b-a337a361b66b.pdf_page3.json
# Wrote 30 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_eff55361-0e39-53a1-da0b-a337a361b66b.pdf_page2.json
# Wrote 39 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_e8d41204-64eb-9f4b-608e-5593933aca41.pdf_page4.json
# Wrote 35 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_fdf168ea-c840-1465-710a-762427b285c3.pdf_page1.json
# Wrote 23 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_f56e2fc1-7f41-68e3-bfe5-06176b9a2e8a.pdf_page2.json
# Wrote 35 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_f9a59888-b508-9792-d356-1d36de82c212.pdf_page1.json
# Wrote 39 entities to /Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/AD_BUY_AUTO_LABELS/Qwen2.5-72B-Instruct-per_page_votes_merged/votes_eabf486e-2ff6-c060-68b7-fcf5363bde66.pdf_page2.json
# m: 0
# Annotators Accuracy : [] for PII type : Person Name
# Annotators Accuracy : [] for PII type : Organization Name
# Annotators Accuracy : [] for PII type : Date
# Annotators Accuracy : [] for PII type : ('Contract Number', 'Invoice Number')
# Annotators Accuracy : [] for PII type : Contract Number
# Annotators Accuracy : [] for PII type : Location
# Annotators Accuracy : [] for PII type : Phone Number
# Annotators Accuracy : [] for PII type : ('Location', 'Organization Name')
# Annotators Accuracy : [] for PII type : Email Address
# Annotators Accuracy : [] for PII type : ('Person Name', 'Organization Name')
# Annotators Accuracy : [] for PII type : Invoice Number
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 18
#      10 annotation_filters.process_directory_to_json(
#      11         in_dir=votes_out_dir,
#      12         out_dir=votes_merged_dir,
#      13         iou_thresh=0.5,
#      14         overlap_thresh=0.9
#      15 )
#      17 score_dir = out_path + MODEL_DIR + "/"
# ---> 18 score.score_all_jsons_global(votes_merged_dir, out_dir=score_dir)
#
# File /Volumes/MyDataDrive/thesis/code-2/src/labelrix/score.py:274, in score_all_jsons_global(votes_dir, out_dir)
#     272 records_by_file[path][local_idx]['probability'] = float(p)
#     273 file_name = path.split("/")[-1].split(".")[0] + ".png"
# --> 274 bb = dimensions_map[file_name]
#     276 # Here we change to abosolute bbox
#     277 x = records_by_file[path][local_idx]['bbox'][0] * bb['original_width']
#
# KeyError: 'votes_e8d41204-64eb-9f4b-608e-5593933aca41.png'
