# %%
import os
import json
import numpy as np
from typing import List, Dict, Any
from typing import List, Dict, Any
import random
from collections import defaultdict

# %%
label_map = {
    "Phone Number": "Phone Number",
    "Mobile Number": "Phone Number",
    "Postal Home Address": "Location",
    "Postal Work Address": "Location",
    "Postal Address" :"Location",
    "Date of Birth": "Date",
    "Full Date": "Date",
    "Sex": "Gender",
    "Gender": "Gender",
    "Natural Person Name": "Person Name",
}

# %%
def load_dimensions_map(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)

    file_dimensions_map = {}

    for entry in data:
        file_name = entry.get("data", {}).get("ocr")
        if file_name:
            file_name = file_name.split("/")[-1]  # Extract just the filename (e.g., votes_fhfb0066_page1.png)

            # Get the first result object from annotations
            results = entry.get("annotations", [])[0].get("result", [])
            if results:
                first_result = results[0]
                width = first_result.get("original_width")
                height = first_result.get("original_height")

                if width is not None and height is not None:
                    file_dimensions_map[file_name] = {
                        "original_width": width,
                        "original_height": height
                    }

    return file_dimensions_map

json_file_path = "/Volumes/MyDataDrive/thesis/code-2/data/manual-label-2.json"  # Replace with actual path
dimensions_map = load_dimensions_map(json_file_path)

# %%
# def estimate_accuracies_triplet(L: np.ndarray, eps: float = 1e-12) -> np.ndarray:
#     """
#     Triplet-based accuracy estimation (Fu et al., 2020).
#     L: binary matrix of shape (n_spans, n_annotators).
#     Returns: array of length m with estimated accuracies in [0,1].
#     """
#     # print(L)
#     n, m = L.shape
#     # print(m)
#     # 1) Compute pairwise agreement rates r_{j,k}
#     r = np.array([[ (L[:, j] * L[:, k]).mean() for k in range(m) ]
#                   for j in range(m)])
#     # 2) If fewer than 3 annotators, default to perfect accuracy
#     if m < 3:
#         return np.ones(m)

#     # 3) For each annotator j, estimate a_j from all triplets (j,k,l)
#     a = np.ones(m)
#     for j in range(m):
#         estimates = []
#         others = [x for x in range(m) if x != j]
#         # iterate over all unordered pairs (k,l)
#         for idx_k in range(len(others)):
#             for idx_l in range(idx_k + 1, len(others)):
#                 k = others[idx_k]
#                 l = others[idx_l]
#                 denom = r[k, l] + eps
#                 if denom > 0:
#                     est = np.sqrt((r[j, k] * r[j, l]) / denom)
#                     estimates.append(est)
#         # aggregate via median
#         if estimates:
#             a[j] = float(np.median(estimates))
#     return a


# def infer_probs(L: np.ndarray, a: np.ndarray, pi: float = 0.5) -> np.ndarray:
#     """
#     Infer posterior probability for each span given label matrix L and accuracies a.
#     """
#     n = L.shape[0]
#     posts = np.zeros(n, dtype=float)
#     for i in range(n):
#         S_p, S_m = pi, 1 - pi
#         for j in range(len(a)):
#             if L[i, j] == 1:
#                 S_p *= (1 + a[j]) / 2
#                 S_m *= (1 - a[j]) / 2
#         posts[i] = S_p / (S_p + S_m)
#     return posts


# def score_one_file(json_path: str):
#     """
#     Load a votes_*.json, compute triplet-based accuracies and posteriors,
#     attach 'probability' to each record, and write out *_scored.json.
#     """
#     # load original records
#     with open(json_path, 'r') as f:
#         items: List[Dict[str, Any]] = json.load(f)

#     # determine annotator count
#     all_anns = {ann for rec in items for ann in rec['annotators']}
#     m = max(all_anns) + 1

#     # build label matrix L: spans × annotators
#     n = len(items)
#     L = np.zeros((n, m), dtype=int)
#     for i, rec in enumerate(items):
#         for ann in rec['annotators']:
#             L[i, ann] = 1

#     # estimate accuracies with triplet method
#     a = estimate_accuracies_triplet(L)

#     # infer posterior probabilities for each span
#     posts = infer_probs(L, a)

#     # attach and write out
#     for i, rec in enumerate(items):
#         rec['probability'] = float(posts[i])

#     str_id  = str(random.randint(1,1000))
#     out_path = f"/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/test/{str_id}.json"
#     with open(out_path, 'w') as f:
#         json.dump(items, f, indent=4)
#     print(f"Wrote scored file: {out_path}")


# def score_all_jsons(votes_dir: str):
#     """
#     Process all votes_*.json in votes_dir.
#     """
#     for fn in os.listdir(votes_dir):
#         if fn.startswith('votes_') and fn.endswith('.json'):
#             score_one_file(os.path.join(votes_dir, fn))

# %%
def estimate_accuracies_triplet(L: np.ndarray, eps: float = 1e-12) -> np.ndarray:
    """
    Triplet-based accuracy estimation (Fu et al., 2020).
    L: binary matrix of shape (n_spans, n_annotators).
    Returns: array of length m with estimated accuracies in [0,1].
    """
    n, m = L.shape
    # Pairwise agreement rates
    r = np.array([[ (L[:, j] * L[:, k]).mean() for k in range(m) ] for j in range(m)])
    if m < 3:
        return np.ones(m)
    # Triplet-based estimates
    a = np.ones(m)
    for j in range(m):
        estimates: List[float] = []
        others = [o for o in range(m) if o != j]
        for idx_k in range(len(others)):
            for idx_l in range(idx_k + 1, len(others)):
                k, l = others[idx_k], others[idx_l]
                denom = r[k, l] + eps
                if denom > 0:
                    estimates.append(np.sqrt((r[j, k] * r[j, l]) / denom))
        if estimates:
            a[j] = float(np.median(estimates))
    return a


def infer_probs(L: np.ndarray, a: np.ndarray, pi: float = 0.5) -> np.ndarray:
    """
    Compute posterior probability for each span given L and accuracies.
    """
    n = L.shape[0]
    posts = np.zeros(n, dtype=float)
    for i in range(n):
        S_p, S_m = pi, 1 - pi
        for j, vote in enumerate(L[i]):
            if vote:
                S_p *= (1 + a[j]) / 2
                S_m *= (1 - a[j]) / 2
        posts[i] = S_p / (S_p + S_m)
    return posts


def score_all_jsons_global(votes_dir: str):
    """
    Process all votes_*.json: group spans by PII type across all files,
    compute triplet-based accuracies & posteriors per type,
    attach probabilities, and write scored files.
    """
    # 1) Load files
    records_by_file: Dict[str, List[Dict[str, Any]]] = {}
    all_recs: List[Dict[str, Any]] = []
    order_map: List[tuple] = []  # (file_path, local_index)
    for fname in sorted(os.listdir(votes_dir)):
        if not (fname.startswith('votes_') and fname.endswith('.json')):
            continue
        path = os.path.join(votes_dir, fname)
        with open(path, 'r') as f:
            items = json.load(f)
        records_by_file[path] = items
        for idx, rec in enumerate(items):
            all_recs.append(rec)
            order_map.append((path, idx))

    if not all_recs:
        print("No vote files to process.")
        return

    # 2) Determine number of annotators
    all_anns = {ann for rec in all_recs for ann in rec.get('annotators', [])}
    m = max(all_anns) + 1 if all_anns else 0

    # 3) Group indices by PII type (hashable key)
    type_to_indices: Dict[Any, List[int]] = defaultdict(list)
    for idx, rec in enumerate(all_recs):
        key = rec.get('pii_type')
        # normalize list keys to tuple
        if isinstance(key, list):
            key = tuple(key)
        type_to_indices[key].append(idx)

    # 4) Compute probabilities per type
    probs = np.zeros(len(all_recs), dtype=float)
    for pii_type, idxs in type_to_indices.items():
        # Build label matrix for this type
        L = np.zeros((len(idxs), m), dtype=int)
        for row_i, rec_idx in enumerate(idxs):
            for ann in all_recs[rec_idx].get('annotators', []):
                L[row_i, ann] = 1
        # Estimate accuracies & infer posteriors
        a = estimate_accuracies_triplet(L)
        posts = infer_probs(L, a)
        for i, rec_idx in enumerate(idxs):
            probs[rec_idx] = posts[i]

    # 5) Attach probabilities back in each file's list
    for (path, local_idx), p in zip(order_map, probs.tolist()):
        records_by_file[path][local_idx]['probability'] = float(p)
        file_name = path.split("/")[-1].split(".")[0] + ".png"
        bb = dimensions_map[file_name]

        # Here we change to abosolute bbox
        x = records_by_file[path][local_idx]['bbox'][0] * bb['original_width']
        y = records_by_file[path][local_idx]['bbox'][1] * bb['original_height']
        width =  records_by_file[path][local_idx]['bbox'][2] * bb['original_width']
        height = records_by_file[path][local_idx]['bbox'][3] * bb['original_height']

        x0 = round(x)
        y0 = round(y)
        x1 = round(width)
        y1 = round(height)

        int_bbox = [x0, y0, x1, y1]

        records_by_file[path][local_idx]['bbox'] = int_bbox


        if isinstance(records_by_file[path][local_idx]['pii_type'], list):
            new_list = []
            for i in records_by_file[path][local_idx]['pii_type']:
                new_list.append(label_map.get(i, i))
            records_by_file[path][local_idx]['pii_type'] = new_list
        else:
            records_by_file[path][local_idx]['pii_type'] = label_map.get(
                records_by_file[path][local_idx]['pii_type'],
                records_by_file[path][local_idx]['pii_type']
            )

        print(records_by_file[path][local_idx]['pii_type'])


    # 5: write back per file
    for path, items in records_by_file.items():
        # out_path = path.replace('.json', '_scored.json')
        file_name = path.split("/")[-1]
        out_path = f"/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/test-final/{file_name}"
        print(f"For : {path} is : {str_id}")
        with open(out_path, 'w') as f:
            json.dump(items, f, indent=4)
        print(f"Wrote scored file: {out_path}")

# %%
# # No pii type spliting 
# def estimate_accuracies_triplet(L: np.ndarray, eps: float = 1e-12) -> np.ndarray:
#     """
#     Triplet-based accuracy estimation (Fu et al., 2020).
#     L: binary matrix of shape (n_spans, n_annotators).
#     Returns: array of length m with estimated accuracies in [0,1].
#     """
#     n, m = L.shape
#     # Compute pairwise agreement rates
#     r = np.array([[ (L[:, j] * L[:, k]).mean() for k in range(m) ]
#                   for j in range(m)])
#     if m < 3:
#         return np.ones(m)
#     # Triplet-based estimates
#     a = np.ones(m)
#     for j in range(m):
#         estimates: List[float] = []
#         others = [o for o in range(m) if o != j]
#         for idx_k in range(len(others)):
#             for idx_l in range(idx_k + 1, len(others)):
#                 k, l = others[idx_k], others[idx_l]
#                 denom = r[k, l] + eps
#                 if denom > 0:
#                     estimates.append(np.sqrt((r[j, k] * r[j, l]) / denom))
#         if estimates:
#             a[j] = float(np.median(estimates))
#     return a


# def infer_probs(L: np.ndarray, a: np.ndarray, pi: float = 0.5) -> np.ndarray:
#     """
#     Compute posterior probability for each span given L and accuracies.
#     """
#     n = L.shape[0]
#     posts = np.zeros(n, dtype=float)
#     for i in range(n):
#         S_p, S_m = pi, 1 - pi
#         for j, vote in enumerate(L[i]):
#             if vote:
#                 S_p *= (1 + a[j]) / 2
#                 S_m *= (1 - a[j]) / 2
#         posts[i] = S_p / (S_p + S_m)
#     return posts


# def score_all_jsons_global(votes_dir: str):
#     """
#     Process all votes_*.json: build one global label matrix across all spans,
#     compute triplet-based accuracies, infer probabilities,
#     attach probabilities, and write scored files.
#     """
#     # 1) Load all files and flatten records
#     records_by_file: Dict[str, List[Dict[str, Any]]] = {}
#     all_recs: List[Dict[str, Any]] = []
#     order_map: List[tuple] = []  # (file_path, local_index)

#     for fname in sorted(os.listdir(votes_dir)):
#         if not (fname.startswith('votes_') and fname.endswith('.json')):
#             continue
#         path = os.path.join(votes_dir, fname)
#         with open(path, 'r') as f:
#             items = json.load(f)
#         records_by_file[path] = items
#         for idx, rec in enumerate(items):
#             all_recs.append(rec)
#             order_map.append((path, idx))

#     if not all_recs:
#         print("No vote files to process.")
#         return

#     # 2) Determine annotator count
#     all_anns = {ann for rec in all_recs for ann in rec.get('annotators', [])}
#     m = max(all_anns) + 1 if all_anns else 0

#     # 3) Build global label matrix L: spans x annotators
#     n = len(all_recs)
#     L = np.zeros((n, m), dtype=int)
#     for i, rec in enumerate(all_recs):
#         for ann in rec.get('annotators', []):
#             L[i, ann] = 1

#     # 4) Estimate accuracies and infer probabilities
#     a = estimate_accuracies_triplet(L)
#     posts = infer_probs(L, a)

#     # 5) Attach probabilities back to records
#     for (path, local_idx), p in zip(order_map, posts.tolist()):
#         records_by_file[path][local_idx]['probability'] = float(p)

#     # 6) Write each scored file
#     for path, items in records_by_file.items():
#         str_id  = str(random.randint(1,1000))
#         file_name = path.split("/")[-1]
#         out_path = f"/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/test-final/{file_name}"
#         print(f"For : {path} is : {str_id}")
#         with open(out_path, 'w') as f:
#             json.dump(items, f, indent=4)
#         print(f"Wrote scored file: {out_path}")

# %%
if __name__ == '__main__':
    # set this to your directory of JSON votes files
    score_all_jsons_global('/Volumes/MyDataDrive/thesis/code-2/src/weak-labels/Qwen3-8B-per_page_votes_merged/')
# Out:
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Phone Number
# ['Phone Number', 'Phone Number']
# Phone Number
# ['Phone Number', 'Phone Number']
# Location
# Location
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# Date
# Date
# ['Invoice Number', 'Contract Number']
# Person Name
# Email Address
# Email Address
# Organization Name
# Person Name
# Email Address
# Person Name
# Person Name
# Email Address
# Phone Number
# ['Phone Number', 'Phone Number']
# Location
# Organization Name
# Date
# Date
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Phone Number
# ['Phone Number', 'Phone Number']
# Location
# Organization Name
# Date
# Date
# Date
# ['Invoice Number', 'Contract Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Location
# Organization Name
# Date
# Person Name
# Person Name
# Person Name
# ['Invoice Number', 'Contract Number', 'Phone Number']
# Location
# Organization Name
# Date
# ['Invoice Number', 'Contract Number']
# Organization Name
# Person Name
# Person Name
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Date
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Organization Name
# Organization Name
# Organization Name
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# Location
# ['Invoice Number', 'Contract Number', 'Organization Name']
# Organization Name
# Organization Name
# Invoice Number
# Invoice Number
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# ['Location', 'Contract Number']
# ['Contract Number', 'Organization Name']
# ['Contract Number', 'Organization Name']
# ['Date', 'Contract Number']
# ['Location', 'Contract Number']
# Contract Number
# Contract Number
# Contract Number
# ['Contract Number', 'Location']
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# ['Contract Number', 'ID Card Number', 'Person Name']
# ['Contract Number', 'ID Card Number', 'Person Name']
# Person Name
# Person Name
# Person Name
# Person Name
# ['Contract Number', 'Person Name']
# Person Name
# Person Name
# Person Name
# Date
# Date
# ['Contract Number', 'ID Card Number']
# Person Name
# Person Name
# ID Card Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Person Name
# Person Name
# Email Address
# Email Address
# Email Address
# Organization Name
# Organization Name
# Organization Name
# Date
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Email Address
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Location
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number', 'Phone Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number', 'Phone Number']
# Organization Name
# Organization Name
# Organization Name
# Person Name
# Date
# Date
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Date
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# ['Phone Number', 'Phone Number']
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Location
# Organization Name
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Date
# ['Invoice Number', 'Contract Number']
# Person Name
# Person Name
# Phone Number
# Phone Number
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Location
# Organization Name
# Organization Name
# Date
# ['Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Date
# Date
# Invoice Number
# Invoice Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Email Address
# Phone Number
# ['Phone Number', 'Phone Number']
# Phone Number
# Location
# Organization Name
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Location', 'ID Card Number']
# Organization Name
# Organization Name
# Organization Name
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Location', 'Contract Number']
# ['Location', 'Contract Number']
# ['Location', 'Contract Number']
# ['Location', 'Contract Number']
# ['Date', 'Contract Number']
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Phone Number
# Phone Number
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number', 'Phone Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number', 'Phone Number']
# ['Invoice Number', 'Contract Number']
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# Location
# Organization Name
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Organization Name
# Date
# Person Name
# Person Name
# Email Address
# Email Address
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# Organization Name
# Date
# Email Address
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Date
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# Organization Name
# Person Name
# Person Name
# Location
# Organization Name
# Organization Name
# Date
# Date
# Date
# Date
# Date
# Date
# Date
# Date
# Date
# Contract Number
# Contract Number
# Contract Number
# ['Invoice Number', 'Contract Number']
# Location
# Organization Name
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number', 'Phone Number']
# Contract Number
# Person Name
# Person Name
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['ID Card Number', 'Phone Number', 'Phone Number']
# ['ID Card Number', 'Phone Number', 'Phone Number']
# Date
# Date
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Invoice Number
# Person Name
# Person Name
# Organization Name
# Date
# Location
# ['Contract Number', 'Organization Name']
# Organization Name
# Organization Name
# Organization Name
# Date
# Contract Number
# Person Name
# Person Name
# Location
# Location
# Organization Name
# Organization Name
# ['Invoice Number', 'Contract Number']
# Date
# Contract Number
# ['Invoice Number', 'Contract Number']
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Organization Name
# Date
# Contract Number
# Invoice Number
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Date
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# ['Invoice Number', 'Contract Number', 'Organization Name']
# ['Contract Number', 'Organization Name']
# ['Contract Number', 'Organization Name']
# Date
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Invoice Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Organization Name
# Organization Name
# Date
# Date
# ['Contract Number', 'Organization Name']
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Invoice Number
# Invoice Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Date
# Organization Name
# Person Name
# Person Name
# Person Name
# Location
# Organization Name
# Organization Name
# Date
# Contract Number
# Organization Name
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Location
# Organization Name
# Organization Name
# Organization Name
# Date
# Date
# Person Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Organization Name
# Organization Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# ['Contract Number', 'Organization Name']
# Organization Name
# Date
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number', 'Organization Name']
# Invoice Number
# Contract Number
# Person Name
# Person Name
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Organization Name']
# Organization Name
# Date
# Date
# ID Card Number
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Phone Number
# Phone Number
# Phone Number
# Phone Number
# Phone Number
# Location
# Organization Name
# Organization Name
# Date
# ['Contract Number', 'ID Card Number']
# ID Card Number
# Contract Number
# ['Invoice Number', 'Contract Number']
# Location
# Location
# Location
# Organization Name
# ['Contract Number', 'Organization Name']
# ['Invoice Number', 'Contract Number']
# Invoice Number
# Person Name
# Organization Name
# Person Name
# Person Name
# Organization Name
# ['Invoice Number', 'Contract Number', 'Organization Name']
# Organization Name
# Date
# Contract Number
# Contract Number
# Organization Name
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Location
# Organization Name
# Date
# Person Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Contract Number
# Person Name
# Person Name
# ['Organization Name', 'Person Name']
# Person Name
# Person Name
# Person Name
# ['Organization Name', 'Person Name']
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number']
# Organization Name
# Person Name
# ['Organization Name', 'Person Name']
# ['Organization Name', 'Person Name']
# ['Organization Name', 'Person Name']
# ['Organization Name', 'Person Name']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Date
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Date
# Invoice Number
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Location
# Location
# Location
# Location
# Organization Name
# Organization Name
# Organization Name
# Date
# Organization Name
# ['Email Address', 'ID Card Number', 'Contract Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number', 'Phone Number']
# Person Name
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Location
# Organization Name
# Organization Name
# Organization Name
# Date
# Contract Number
# ['Invoice Number', 'Contract Number']
# Person Name
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Organization Name
# Date
# Date
# ID Card Number
# ['Invoice Number', 'Contract Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Organization Name
# Person Name
# Person Name
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Gender', 'Person Name']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Location
# Location
# Organization Name
# Date
# Date
# Contract Number
# ['Invoice Number', 'Contract Number']
# Person Name
# Location
# ID Card Number
# ['Invoice Number', 'ID Card Number']
# Organization Name
# Gender
# Gender
# Gender
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Phone Number
# ['Phone Number', 'Phone Number']
# Phone Number
# Phone Number
# ['Phone Number', 'Phone Number']
# Phone Number
# Organization Name
# Organization Name
# Organization Name
# Date
# Date
# Date
# Date
# ['Invoice Number', 'Contract Number']
# Organization Name
# Person Name
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Organization Name
# Organization Name
# ['Organization Name', 'Person Name']
# Date
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# Person Name
# Organization Name
# ['Date', 'Contract Number']
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Organization Name']
# Contract Number
# Date
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Invoice Number
# Invoice Number
# Person Name
# Invoice Number
# Invoice Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# ['Phone Number', 'Phone Number']
# Phone Number
# Phone Number
# Phone Number
# Location
# ['Location', 'Person Name']
# Location
# Location
# Location
# Location
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Location
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Organization Name
# Organization Name
# Organization Name
# ['Contract Number', 'Organization Name']
# Date
# Person Name
# Person Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Date
# Person Name
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Organization Name
# Date
# Date
# Date
# Date
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number', 'Phone Number']
# Organization Name
# Organization Name
# Person Name
# Location
# Location
# Organization Name
# Organization Name
# Date
# Location
# Location
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Date
# Date
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# Person Name
# Person Name
# Location
# Location
# Location
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'ID Card Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Phone Number
# Phone Number
# ['Phone Number', 'Phone Number']
# Phone Number
# Phone Number
# Phone Number
# ['Phone Number', 'Phone Number']
# Phone Number
# Organization Name
# ['Location', 'Organization Name']
# Organization Name
# ['Location', 'Organization Name']
# Date
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Organization Name', 'Person Name']
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# ['Contract Number', 'Organization Name']
# Organization Name
# Date
# Date
# ['Contract Number', 'Organization Name']
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Person Name
# Person Name
# Organization Name
# Organization Name
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Date
# Person Name
# Person Name
# Person Name
# Person Name
# Phone Number
# Phone Number
# Phone Number
# Phone Number
# ['Contract Number', 'Organization Name']
# Date
# Date
# ['Invoice Number', 'Contract Number']
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Person Name
# Person Name
# Organization Name
# Organization Name
# Organization Name
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# ['Contract Number', 'Organization Name']
# Date
# Gender
# Gender
# Contract Number
# Phone Number
# Contract Number
# Person Name
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Location
# Location
# Organization Name
# Organization Name
# Date
# Location
# Location
# Location
# Location
# Person Name
# Person Name
# Email Address
# Phone Number
# ['Phone Number', 'Phone Number']
# Organization Name
# Organization Name
# Date
# Date
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# ID Card Number
# Contract Number
# ['Invoice Number', 'Contract Number']
# Date
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Invoice Number', 'Contract Number', 'ID Card Number', 'Phone Number']
# Organization Name
# Date
# Person Name
# Person Name
# Person Name
# Person Name
# Organization Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# Location
# Location
# Location
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number', 'Phone Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# Organization Name
# Person Name
# Location
# Location
# Location
# Location
# Organization Name
# Date
# ['Invoice Number', 'Contract Number']
# Contract Number
# Person Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Location
# Location
# Location
# Location
# Location
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number']
# Location
# Location
# Person Name
# Person Name
# Person Name
# Organization Name
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Organization Name
# Organization Name
# Contract Number
# ['ID Card Number', 'Phone Number', 'Phone Number']
# Organization Name
# Organization Name
# Date
# Gender
# Gender
# Gender
# ['Invoice Number', 'Contract Number']
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# Location
# Location
# Location
# Organization Name
# Organization Name
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Email Address
# Email Address
# Email Address
# Email Address
# Phone Number
# Phone Number
# Phone Number
# Phone Number
# ['Phone Number', 'Phone Number']
# Location
# Location
# Location
# Organization Name
# Date
# Date
# Date
# Date
# Date
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# Person Name
# Date
# Date
# Person Name
# Person Name
# ['Invoice Number', 'Phone Number', 'Phone Number', 'Contract Number', 'ID Card Number']
# Organization Name
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Phone Number
# Phone Number
# Date
# Date
# Date
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Contract Number
# ['Invoice Number', 'Contract Number']
# Person Name
# Person Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# Location
# Location
# Organization Name
# Organization Name
# Organization Name
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# ['Contract Number', 'Person Name']
# Person Name
# ['Contract Number', 'Organization Name']
# ['Contract Number', 'Organization Name']
# ['Date', 'Contract Number']
# Date
# Organization Name
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Date
# ['Invoice Number', 'Contract Number', 'ID Card Number']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# Organization Name
# Organization Name
# Organization Name
# ['Contract Number', 'Organization Name']
# Organization Name
# Contract Number
# Organization Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Contract Number', 'Organization Name']
# Date
# Date
# ['Contract Number', 'Person Name']
# Phone Number
# Phone Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Contract Number
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Organization Name
# Date
# ID Card Number
# ['Contract Number', 'Organization Name']
# ['Invoice Number', 'Contract Number']
# ['Invoice Number', 'Contract Number']
# Organization Name
# Organization Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Invoice Number', 'Contract Number', 'Organization Name']
# Organization Name
# Date
# ['Organization Name', 'Person Name']
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# Person Name
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# ['Phone Number', 'Phone Number']
# Location
# Location
# Date
# Person Name
# Person Name
# ['Invoice Number', 'Organization Name']
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Organization Name
# Date
# ['Invoice Number', 'Contract Number']
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Invoice Number
# Person Name
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgbf0249_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgbf0249_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgbf0249_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgbf0249_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgbf0249_page5.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgbf0249_page5.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgcg0076_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgcg0076_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgck0201_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgck0201_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgcn0082_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgcn0082_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgdl0043_page3.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgdl0043_page3.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgdn0202_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgdn0202_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgdp0140_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgdp0140_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgdy0093_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgdy0093_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgfv0233_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgfv0233_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgfy0251_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgfy0251_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fggl0102_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fggl0102_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgjc0018_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgjc0018_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgjj0009_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgjj0009_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgjy0234_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgjy0234_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgjy0234_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgjy0234_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fglj0241_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fglj0241_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgll0036_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgll0036_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fglw0150_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fglw0150_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fglx0238_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fglx0238_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgmp0189_page3.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgmp0189_page3.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgmp0191_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgmp0191_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgng0218_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgng0218_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgnh0009_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgnh0009_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgnn0231_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgnn0231_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgpb0239_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgpb0239_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgpd0104_page3.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgpd0104_page3.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgpg0139_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgpg0139_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgph0228_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgph0228_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgvd0138_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgvd0138_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgvg0019_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgvg0019_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgvk0122_page3.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgvk0122_page3.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgvl0222_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgvl0222_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgvv0063_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgvv0063_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgwb0124_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgwb0124_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgwj0106_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgwj0106_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgwj0106_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgwj0106_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgwk0174_page4.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgwk0174_page4.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgwm0211_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgwm0211_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgxc0224_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgxc0224_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgxc0224_page5.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgxc0224_page5.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgxw0053_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgxw0053_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgyk0087_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgyk0087_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgyk0087_page3.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgyk0087_page3.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgyv0152_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fgyv0152_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhbd0057_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhbd0057_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhbh0030_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhbh0030_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhbh0177_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhbh0177_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhcv0056_page1.json is : 66
# ...
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhfg0219_page6.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhfg0219_page6.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhfh0230_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhfh0230_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhfx0251_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhfx0251_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhgx0106_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhgx0106_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhhd0023_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhhd0023_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhhh0238_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhhh0238_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhhj0137_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhhj0137_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhhp0238_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhhp0238_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhjd0139_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhjd0139_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhkm0113_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhkm0113_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhkm0251_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhkm0251_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhkm0251_page3.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhkm0251_page3.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhlv0084_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhlv0084_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhmb0046_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhmb0046_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhmb0151_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhmb0151_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhmj0169_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhmj0169_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhmm0017_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhmm0017_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhmn0095_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhmn0095_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhnm0001_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhnm0001_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhpb0032_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhpb0032_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhpy0150_page8.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhpy0150_page8.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhvb0035_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhvb0035_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhvc0235_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhvc0235_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhvj0109_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhvj0109_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhvy0227_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhvy0227_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhxh0140_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhxh0140_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhxj0190_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhxj0190_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhxk0019_page5.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhxk0019_page5.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhyg0091_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhyg0091_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhyg0141_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhyg0141_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhyg0235_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhyg0235_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhyh0038_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhyh0038_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhyn0144_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhyn0144_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fhyx0253_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fhyx0253_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjbk0069_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjbk0069_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjbv0033_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjbv0033_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjbw0138_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjbw0138_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjcc0074_page4.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjcc0074_page4.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjcx0221_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjcx0221_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjcx0221_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjcx0221_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjdl0137_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjdl0137_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjdx0222_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjdx0222_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjff0148_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjff0148_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjfw0152_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjfw0152_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjgh0000_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjgh0000_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjjc0186_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjjc0186_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjjn0020_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjjn0020_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjjn0191_page2.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjjn0191_page2.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjkb0133_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjkb0133_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjkm0063_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjkm0063_page1.json
# For : /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fjlf0106_page1.json is : 66
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test-final/votes_fjlf0106_page1.json

# %%
json_path = "/Volumes/MyDataDrive/thesis/code-2/src/weak-labels/Qwen3-8B-per_page_votes_merged/votes_fgfv0233_page1.json"
score_one_file(json_path)
# Out:
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test.json

# %%
str_id  = random.randint(1,1000)
print(str_id)
# Out:
# 66

# %%
if __name__ == '__main__':
    # adjust to your JSON directory
    score_all_jsons('/Volumes/MyDataDrive/thesis/code-2/src/weak-labels/Qwen3-8B-per_page_votes_merged')
# Out:
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/111.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/953.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/237.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/90.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/593.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/749.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/812.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/285.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/27.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/437.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/221.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/844.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/131.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/869.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/408.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/702.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/518.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/236.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/360.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/126.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/401.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/88.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/667.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/877.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/167.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/632.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/35.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/86.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/847.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/166.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/576.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/125.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/452.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/54.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/471.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/989.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/239.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/10.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/727.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/654.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/662.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/699.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/471.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/465.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/933.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/649.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/999.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/911.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/192.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/453.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/920.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/385.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/969.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/478.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/756.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/738.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/728.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/672.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/496.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/720.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/571.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/314.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/91.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/356.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/509.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/205.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/679.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/979.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/159.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/890.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/522.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/903.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/768.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/193.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/84.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/197.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/73.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/374.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/886.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/848.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/160.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/499.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/891.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/435.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/70.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/157.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/434.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/911.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/661.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/4.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/733.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/57.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/183.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/961.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/509.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/576.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/305.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/524.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/550.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/757.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/159.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/578.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/10.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/981.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/466.json
# Wrote scored file: /Volumes/MyDataDrive/thesis/rvl-test-preprocessing/src/rvl_test_preprocessing/weak-labels-algo/test/174.json

# %%
def score_all_jsons_global(votes_dir: str):
    """
    Process all votes_*.json: group spans by PII type across all files,
    compute triplet-based accuracies & posteriors per type,
    attach probabilities, and write scored files.
    """
    # 1) Load files
    pii_types = set()
    for fname in sorted(os.listdir(votes_dir)):
        if not (fname.startswith('votes_') and fname.endswith('.json')):
            continue
        path = os.path.join(votes_dir, fname)
        with open(path, 'r') as f:
            items = json.load(f)
        for idx, rec in enumerate(items):
            if isinstance(rec['pii_type'], list) and len(rec['pii_type']) > 1:
                pii_types.add(rec['pii_type'][0])
            else:
                pii_types.add(rec['pii_type'])
    
    print(pii_types)


score_all_jsons_global("/Volumes/MyDataDrive/thesis/code-2/src/weak-labels-algo/test-final")
# Out:
# {'ID Card Number', 'Sex', 'Email Address', 'Invoice Number', 'Phone Number', 'Contract Number', 'Full Date', 'Postal Address', 'Organization Name', 'Natural Person Name'}

# %%
import json

def load_dimensions_map(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)

    file_dimensions_map = {}

    for entry in data:
        file_name = entry.get("data", {}).get("ocr")
        if file_name:
            file_name = file_name.split("/")[-1]  # Extract just the filename (e.g., votes_fhfb0066_page1.png)

            # Get the first result object from annotations
            results = entry.get("annotations", [])[0].get("result", [])
            if results:
                first_result = results[0]
                width = first_result.get("original_width")
                height = first_result.get("original_height")

                if width is not None and height is not None:
                    file_dimensions_map[file_name] = {
                        "original_width": width,
                        "original_height": height
                    }

    return file_dimensions_map

# Example usage
json_file_path = "/Volumes/MyDataDrive/thesis/code-2/data/manual-label-2.json"  # Replace with actual path
dimensions_map = load_dimensions_map(json_file_path)

# Query like this
print(dimensions_map["votes_fgbf0249_page1.png"])
# Output: {'original_width': 1728, 'original_height': 2292}
# Out:
# {'original_width': 2550, 'original_height': 3352}
