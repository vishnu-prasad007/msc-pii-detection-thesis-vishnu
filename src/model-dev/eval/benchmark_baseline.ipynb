# %%
import os

# %%
# Here we will evaluate the model on the test set
# Import the directory_benchmark module from the eval directory

import sys
sys.path.append("../../")
from eval.directory_benchmark import benchmark_directories, benchmark_single_file

def benchmark(test_set_labels_dir: str, pred_labels_dir: str, iou_threshold: float = 0.0):
    """
    Benchmark the model on the test set using the new directory_benchmark script
    
    Args:
        test_set_labels_dir: Directory containing ground truth JSON files
        pred_labels_dir: Directory containing prediction JSON files  
        iou_threshold: IoU threshold for bounding box matching (default: 0.5)
    
    Returns:
        pandas.DataFrame: Results dataframe with simplified columns
    """
    return benchmark_directories(test_set_labels_dir, pred_labels_dir, iou_threshold)

def benchmark_from_file(test_data_file: str, pred_labels_dir: str, iou_threshold: float = 0.5):
    """
    Benchmark the model on the test set using a single JSON file containing all test data
    
    Args:
        test_data_file: Path to JSON file containing all ground truth data in format:
                       [{"file_name": "...", "labels": [...]}, ...]
        pred_labels_dir: Directory containing prediction JSON files  
        iou_threshold: IoU threshold for bounding box matching (default: 0.0)
    
    Returns:
        pandas.DataFrame: Results dataframe with simplified columns
    """
    return benchmark_single_file(test_data_file, pred_labels_dir, iou_threshold)

# %%
test_data_file = "/Volumes/MyDataDrive/thesis/code-2/new-data/IIT-CDIP/test/test-data-iit-cdip-840px.json"
pred_labels_dir = "/Volumes/MyDataDrive/thesis/code-2/new-data/benchmarks/trained_model/model_pred/any_annotator/r64_alpha128_train-data-mixed-840px-annotator-1_lr0_000042/checkpoint-94"


results = benchmark_from_file(test_data_file, pred_labels_dir, iou_threshold=0.0)
# Out:
# Loading test data from: /Volumes/MyDataDrive/thesis/code-2/new-data/IIT-CDIP/test/test-data-iit-cdip-840px.json
# Found 100 ground truth files to process
# Files with predictions: 100
# Files without predictions: 0 (will be treated as complete prediction failures)
#
# Counting all ground truth entities...
#   fhfb0066_page1: 3 entities
#   fjcc0074_page4: 17 entities
#   fgbf0249_page5: 31 entities
#   fhbh0030_page1: 10 entities
#   fgcg0076_page1: 5 entities
#   fgdp0140_page1: 11 entities
#   fgvl0222_page1: 25 entities
#   fhvc0235_page2: 57 entities
#   fhnm0001_page1: 86 entities
#   fjgh0000_page1: 10 entities
#   fhyg0141_page1: 15 entities
#   fhyn0144_page1: 12 entities
#   fgvd0138_page1: 16 entities
#   fgvk0122_page3: 7 entities
#   fgvg0019_page1: 6 entities
#   fhhd0023_page2: 8 entities
#   fhkm0113_page1: 6 entities
#   fhxj0190_page1: 12 entities
#   fhvb0035_page1: 16 entities
#   fjbw0138_page1: 7 entities
#   fgfy0251_page1: 17 entities
#   fgmp0189_page3: 21 entities
#   fjjc0186_page2: 9 entities
#   fgxw0053_page1: 8 entities
#   fhvy0227_page2: 1 entities
#   fhhh0238_page1: 29 entities
#   fgwj0106_page2: 13 entities
#   fhjd0139_page2: 5 entities
#   fgxc0224_page5: 7 entities
#   fhmm0017_page2: 3 entities
#   fgfv0233_page1: 10 entities
#   fgck0201_page1: 15 entities
#   fglx0238_page1: 35 entities
#   fgpd0104_page3: 1 entities
#   fhmb0046_page1: 3 entities
#   fjlf0106_page1: 30 entities
#   fhyh0038_page1: 29 entities
#   fjln0143_page4: 1 entities
#   fjcx0221_page2: 8 entities
#   fgwb0124_page1: 11 entities
#   fgph0228_page1: 20 entities
#   fjbk0069_page1: 13 entities
#   fgnh0009_page1: 12 entities
#   fjkb0133_page1: 13 entities
#   fjkm0063_page1: 31 entities
#   fgbf0249_page2: 27 entities
#   fhmn0095_page1: 12 entities
#   fhfh0230_page1: 16 entities
#   fgyk0087_page3: 15 entities
#   fgmp0191_page1: 16 entities
#   fhpy0150_page8: 11 entities
#   fjdx0222_page1: 21 entities
#   fhcv0056_page1: 20 entities
#   fhxk0019_page5: 7 entities
#   fgng0218_page1: 18 entities
#   fgjj0009_page1: 5 entities
#   fjjn0191_page2: 18 entities
#   fglw0150_page1: 7 entities
#   fgdn0202_page1: 5 entities
#   fhfg0219_page4: 13 entities
#   fglj0241_page1: 8 entities
#   fjfw0152_page1: 10 entities
#   fhbd0057_page2: 4 entities
#   fgdy0093_page2: 14 entities
#   fhyx0253_page1: 11 entities
#   fgbf0249_page1: 44 entities
#   fggl0102_page1: 30 entities
#   fhyg0091_page1: 7 entities
#   fhmb0151_page1: 7 entities
#   fgjc0018_page1: 8 entities
#   fjcx0221_page1: 36 entities
#   fgpg0139_page1: 5 entities
#   fgxc0224_page1: 19 entities
#   fhyg0235_page1: 18 entities
#   fgyk0087_page1: 38 entities
#   fhfx0251_page2: 2 entities
#   fgwm0211_page1: 11 entities
#   fhvj0109_page1: 6 entities
#   fhhj0137_page1: 40 entities
#   fhxh0140_page1: 10 entities
#   fjdl0137_page1: 2 entities
#   fhgx0106_page1: 11 entities
#   fgll0036_page1: 13 entities
#   fjff0148_page1: 12 entities
#   fhkm0251_page2: 24 entities
#   fhcw0027_page3: 7 entities
#   fgwj0106_page1: 10 entities
#   fhfg0219_page2: 15 entities
#   fjjn0020_page2: 6 entities
#   fhbh0177_page1: 9 entities
#   fgvv0063_page2: 5 entities
#   fhfg0219_page3: 13 entities
#   fhkm0251_page3: 28 entities
#   fgjy0234_page1: 40 entities
#   fgnn0231_page1: 11 entities
#   fgyv0152_page1: 7 entities
#   fgcn0082_page1: 6 entities
#   fgdl0043_page3: 58 entities
#   fjbv0033_page1: 9 entities
#   fgwk0174_page4: 10 entities
#
# Total Ground Truth Distribution:
# --------------------------------------------------
# Entity Type          GT Count
# --------------------------------------------------
# Contract Number      68
# Date                 178
# Email Address        63
# ID Card Number       8
# Invoice Number       12
# Location             131
# Organization Name    212
# Person Name          767
# Phone Number         84
# Signature            17
# --------------------------------------------------
# TOTAL                1540
# --------------------------------------------------
# Processing: fgbf0249_page1
# Processing: fgbf0249_page2
# Processing: fgbf0249_page5
# Processing: fgcg0076_page1
# Processing: fgck0201_page1
# Processing: fgcn0082_page1
# Processing: fgdl0043_page3
# Processing: fgdn0202_page1
# Processing: fgdp0140_page1
# Processing: fgdy0093_page2
# Processing: fgfv0233_page1
# Processing: fgfy0251_page1
# Processing: fggl0102_page1
# Processing: fgjc0018_page1
# Processing: fgjj0009_page1
# Processing: fgjy0234_page1
# Processing: fglj0241_page1
# Processing: fgll0036_page1
# Processing: fglw0150_page1
# Processing: fglx0238_page1
# Processing: fgmp0189_page3
# Processing: fgmp0191_page1
# Processing: fgng0218_page1
# Processing: fgnh0009_page1
# Processing: fgnn0231_page1
# Processing: fgpd0104_page3
# Processing: fgpg0139_page1
# Processing: fgph0228_page1
# Processing: fgvd0138_page1
# Processing: fgvg0019_page1
# Processing: fgvk0122_page3
# Processing: fgvl0222_page1
# Processing: fgvv0063_page2
# Processing: fgwb0124_page1
# Processing: fgwj0106_page1
# Processing: fgwj0106_page2
# Processing: fgwk0174_page4
# Processing: fgwm0211_page1
# Processing: fgxc0224_page1
# Processing: fgxc0224_page5
# Processing: fgxw0053_page1
# Processing: fgyk0087_page1
# Processing: fgyk0087_page3
# Processing: fgyv0152_page1
# Processing: fhbd0057_page2
# Processing: fhbh0030_page1
# Processing: fhbh0177_page1
# Processing: fhcv0056_page1
# Processing: fhcw0027_page3
# Processing: fhfb0066_page1
# Processing: fhfg0219_page2
# Processing: fhfg0219_page3
# Processing: fhfg0219_page4
# Processing: fhfh0230_page1
# Processing: fhfx0251_page2
# Processing: fhgx0106_page1
# Processing: fhhd0023_page2
# Processing: fhhh0238_page1
# Processing: fhhj0137_page1
# Processing: fhjd0139_page2
# Processing: fhkm0113_page1
# Processing: fhkm0251_page2
# Processing: fhkm0251_page3
# Processing: fhmb0046_page1
# Processing: fhmb0151_page1
# Processing: fhmm0017_page2
# Processing: fhmn0095_page1
# Processing: fhnm0001_page1
# Processing: fhpy0150_page8
# Processing: fhvb0035_page1
# Processing: fhvc0235_page2
# Processing: fhvj0109_page1
# Processing: fhvy0227_page2
# Processing: fhxh0140_page1
# Processing: fhxj0190_page1
# Processing: fhxk0019_page5
# Processing: fhyg0091_page1
# Processing: fhyg0141_page1
# Processing: fhyg0235_page1
# Processing: fhyh0038_page1
# Processing: fhyn0144_page1
# Processing: fhyx0253_page1
# Processing: fjbk0069_page1
# Processing: fjbv0033_page1
# Processing: fjbw0138_page1
# Processing: fjcc0074_page4
# Processing: fjcx0221_page1
# Processing: fjcx0221_page2
# Processing: fjdl0137_page1
# Processing: fjdx0222_page1
# Processing: fjff0148_page1
# Processing: fjfw0152_page1
# Processing: fjgh0000_page1
# Processing: fjjc0186_page2
# Processing: fjjn0020_page2
# Processing: fjjn0191_page2
# Processing: fjkb0133_page1
# Processing: fjkm0063_page1
# Processing: fjlf0106_page1
# Processing: fjln0143_page4
#
# === BENCHMARK RESULTS ===
# Total files processed: 100
# Total rows in results: 1852
#
# Metrics by Entity Type:
# ------------------------------------------------------------------------------------------
# Entity Type          Precision  Recall     F1-Score   TP    FP    FN    GT
# ------------------------------------------------------------------------------------------
# Contract Number      0.35       0.32       0.34       22    41    46    68
# Date                 0.89       0.58       0.71       104   13    74    178
# Email Address        0.75       0.70       0.72       44    15    19    63
# ID Card Number       0.00       0.00       0.00       0     0     8     8
# Invoice Number       0.15       0.17       0.16       2     11    10    12
# Location             0.54       0.66       0.59       86    74    45    131
# Organization Name    0.67       0.29       0.40       61    30    151   212
# Person Name          0.85       0.73       0.79       559   97    208   767
# Phone Number         0.55       0.45       0.50       38    31    46    84
# Signature            0.00       0.00       0.00       0     0     17    17
# ------------------------------------------------------------------------------------------
# OVERALL              0.75       0.59       0.66       916   312   624   1540
# ------------------------------------------------------------------------------------------

# %%
print(results)
# Out:
#          Document ID        Entity Type                  Ground Truth  \
# 0     fgbf0249_page1  Organization Name
# 1     fgbf0249_page1  Organization Name  Mallinckrodt Pharmaceuticals
# 2     fgbf0249_page1  Organization Name                  Mallinckrodt
# 3     fgbf0249_page1  Organization Name                      McKesson
# 4     fgbf0249_page1  Organization Name                       Enclara
# ...              ...                ...                           ...
# 2663  fjlf0106_page1        Person Name                    C. Koehler
# 2664  fjlf0106_page1        Person Name                      D. Watts
# 2665  fjln0143_page4  Organization Name
# 2666  fjln0143_page4    Contract Number
# 2667  fjln0143_page4    Contract Number                6761 5 5 5 5 9
#
#                                               Predicted is_correct  bbox_iou  \
# 0     Mallinckrodt Pharmaceuticals | Specialty Generics      False       0.0
# 1                                                            False       0.0
# 2                                                            False       0.0
# 3                                                            False       0.0
# 4                                                            False       0.0
# ...                                                 ...        ...       ...
# 2663                                                         False       0.0
# 2664                                                         False       0.0
# 2665                                               KOOL      False       0.0
# 2666                                          676155559      False       0.0
# 2667                                                         False  0.245614
#
#      text_similarity
# 0                0.0
# 1           0.857143
# 2           0.748299
# 3           0.529762
# 4           0.571429
# ...              ...
# 2663             0.6
# 2664        0.408333
# 2665             0.0
# 2666             0.0
# 2667        0.880952
#
# [2668 rows x 7 columns]
